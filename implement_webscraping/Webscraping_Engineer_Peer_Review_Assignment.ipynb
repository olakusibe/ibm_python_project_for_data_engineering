# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Peer Review Assignment - Data Engineer - Webscraping

# %% [markdown]
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Objectives
#
# In this part you will:
#
# *   Use webscraping to get bank information

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
#!mamba install pandas==1.3.3 -y
#!mamba install requests==2.26.0 -y
#!mamba install bs4==4.10.0 -y
#!mamba install html5lib==1.1 -y

# !pip install requests
# !pip install bs4
# !pip install html5lib
# Out:
# Requirement already satisfied: requests in c:\python39\lib\site-packages (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python39\lib\site-packages (from requests) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\python39\lib\site-packages (from requests) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python39\lib\site-packages (from requests) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\python39\lib\site-packages (from requests) (3.3)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: There was an error checking the latest version of pip.
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      ------------------------------------ 128.2/128.2 kB 216.0 kB/s eta 0:00:00
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Using legacy 'setup.py install' for bs4, since package 'wheel' is not installed.
# Installing collected packages: soupsieve, beautifulsoup4, bs4
#   Running setup.py install for bs4: started
#   Running setup.py install for bs4: finished with status 'done'
# Successfully installed beautifulsoup4-4.11.1 bs4-0.0.1 soupsieve-2.3.2.post1
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: There was an error checking the latest version of pip.
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ------------------------------------ 112.2/112.2 kB 283.1 kB/s eta 0:00:00
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: six>=1.9 in c:\users\olakunsibe\appdata\roaming\python\python39\site-packages (from html5lib) (1.16.0)
# Installing collected packages: webencodings, html5lib
# Successfully installed html5lib-1.1 webencodings-0.5.1
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
from bs4 import BeautifulSoup
import html5lib
import requests
import pandas as pd

# %% [markdown]
# ## Extract Data Using Web Scraping

# %% [markdown]
# The wikipedia webpage [https://en.wikipedia.org/wiki/List_of_largest_banks](https://en.wikipedia.org/wiki/List_of_largest_banks?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01) provides information about largest banks in the world by various parameters. Scrape the data from the table 'By market capitalization' and store it in a JSON file.

# %% [markdown]
# ### Webpage Contents
#
# Gather the contents of the webpage in text format using the `requests` library and assign it to the variable <code>html_data</code>

# %%
#Write your code here
scrap_url = "https://en.wikipedia.org/wiki/List_of_largest_banks"
html_data = requests.get(scrap_url)

# %% [markdown]
# <b>Question 1</b> Print out the output of the following line, and remember it as it will be a quiz question:

# %%
#html_data[101:124]
question1 = html_data.text[101:124]
print(question1)
# Out:
# List of largest banks -

# %% [markdown]
# ### Scraping the Data
#
# <b> Question 2</b> Using the contents and `beautiful soup` load the data from the `By market capitalization` table into a `pandas` dataframe. The dataframe should have the bank `Name` and `Market Cap (US$ Billion)` as column names.  Display the first five rows using head.

# %% [markdown]
# Using BeautifulSoup parse the contents of the webpage.

# %%
#Replace the dots below
#soup="......"
soup = BeautifulSoup(html_data, features="html5lib")
print(soup.preittify())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Olakunsibe\onedrive\personalgithub\ibm_python_project_for_data_engineering\implement_webscraping\Webscraping_Engineer_Peer_Review_Assignment.ipynb Cell 17 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Olakunsibe/onedrive/personalgithub/ibm_python_project_for_data_engineering/implement_webscraping/Webscraping_Engineer_Peer_Review_Assignment.ipynb#ch0000016?line=0'>1</a> #Replace the dots below
#       <a href='vscode-notebook-cell:/c%3A/Users/Olakunsibe/onedrive/personalgithub/ibm_python_project_for_data_engineering/implement_webscraping/Webscraping_Engineer_Peer_Review_Assignment.ipynb#ch0000016?line=1'>2</a> #soup="......"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Olakunsibe/onedrive/personalgithub/ibm_python_project_for_data_engineering/implement_webscraping/Webscraping_Engineer_Peer_Review_Assignment.ipynb#ch0000016?line=2'>3</a> soup = BeautifulSoup(html_data)
#       <a href='vscode-notebook-cell:/c%3A/Users/Olakunsibe/onedrive/personalgithub/ibm_python_project_for_data_engineering/implement_webscraping/Webscraping_Engineer_Peer_Review_Assignment.ipynb#ch0000016?line=3'>4</a> print(soup.preittify())
#
# File c:\Python39\lib\site-packages\bs4\__init__.py:313, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     311 if hasattr(markup, 'read'):        # It's a file-type object.
#     312     markup = markup.read()
# --> 313 elif len(markup) <= 256 and (
#     314         (isinstance(markup, bytes) and not b'<' in markup)
#     315         or (isinstance(markup, str) and not '<' in markup)
#     316 ):
#     317     # Issue warnings for a couple beginner problems
#     318     # involving passing non-markup to Beautiful Soup.
#     319     # Beautiful Soup will still parse the input as markup,
#     320     # since that is sometimes the intended behavior.
#     321     if not self._markup_is_url(markup):
#     322         self._markup_resembles_filename(markup)
#
# TypeError: object of type 'Response' has no len()

# %% [markdown]
# Load the data from the `By market capitalization` table into a pandas dataframe. The dataframe should have the bank `Name` and `Market Cap (US$ Billion)` as column names. Using the empty dataframe `data` and the given loop extract the necessary data from each row and append it to the empty dataframe.

# %%
data = pd.DataFrame(columns=["Name", "Market Cap (US$ Billion)"])

for row in soup.find_all('tbody')[3].find_all('tr'):
    col = row.find_all('td')
    #Write your code here

# %% [markdown]
# **Question 3** Display the first five rows using the `head` function.

# %%
#Write your code here

# %% [markdown]
# ### Loading the Data
#
# Usually you will Load the `pandas` dataframe created above into a JSON named `bank_market_cap.json` using the `to_json()` function, but this time the data will be sent to another team who will split the data file into two files and inspect it. If you save the data it will interfere with the next part of the assignment.

# %%
#Write your code here

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy, Joseph Santarcangelo and Azim Hirjani

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By          | Change Description                 |
# | ----------------- | ------- | ------------------- | ---------------------------------- |
# | 2022-07-12        | 0.2     | Appalabhaktula Hema | Corrected the code and markdown    |
# | 2020-11-25        | 0.1     | Ramesh Sannareddy   | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation.
